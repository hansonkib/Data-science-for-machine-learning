# %% [markdown]
# ## CLEANING THE DATASETS

# %% [markdown]
# * Renaming the columns

# %%
import pandas as pd
df=pd.read_csv("seattle-weather.csv")
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012/01/01            0.0      12.8       5.0   4.7  drizzle
# 1     2012/01/02           10.9      10.6       2.8   4.5     rain
# 2     2012/01/03            0.8      11.7       7.2   2.3     rain
# 3     2012/01/04           20.3      12.2       5.6   4.7     rain
# 4     2012/01/05            1.3       8.9       2.8   6.1     rain
# 5     2012/01/06            2.5       4.4       2.2   2.2     rain
# 6     2012/01/07            0.0       7.2       2.8   2.3     rain
# 7     2012/01/08            0.0      10.0       2.8   2.0      sun
# 8     2012/01/09            4.3       9.4       5.0   3.4     rain
# 9     2012/01/10            1.0       6.1       0.6   3.4     rain
# 10    2012/01/11            0.0       6.1      -1.1   5.1      sun
# 11    2012/01/12            0.0       6.1      -1.7   1.9      sun
# 12    2012/01/13            0.0       5.0      -2.8   1.3      sun
# ...

# %% [markdown]
# * renaming the column title for wind to wind velocity

# %%
df.rename(columns={"wind":"wind_velocity"})
# Out:
#             date  precipitation  temp_max  temp_min  wind_velocity  weather
# 0     2012/01/01            0.0      12.8       5.0            4.7  drizzle
# 1     2012/01/02           10.9      10.6       2.8            4.5     rain
# 2     2012/01/03            0.8      11.7       7.2            2.3     rain
# 3     2012/01/04           20.3      12.2       5.6            4.7     rain
# 4     2012/01/05            1.3       8.9       2.8            6.1     rain
# 5     2012/01/06            2.5       4.4       2.2            2.2     rain
# 6     2012/01/07            0.0       7.2       2.8            2.3     rain
# 7     2012/01/08            0.0      10.0       2.8            2.0      sun
# 8     2012/01/09            4.3       9.4       5.0            3.4     rain
# 9     2012/01/10            1.0       6.1       0.6            3.4     rain
# 10    2012/01/11            0.0       6.1      -1.1            5.1      sun
# ...

# %% [markdown]
# # filling the null values in the column with the meean values of the column
# * the following snippet can be used to do so

# %%
#df.qsec=df.qsec.fillna(df.qsec.mean())
#df

# %% [markdown]
# # Dropping unwanted coluns from the dataset

# %%
# df.drop(columns=["wind_velocity"])
#df

# %% [markdown]
# ## FINDING THE CORRELATION MATRIX OF THE DATASET ITEMS

# %%
A=df[["date","precipitation","temp_max","temp_min","wind","weather"]].corr()
A
# Out:
#                precipitation  temp_max  temp_min      wind
# precipitation       1.000000 -0.228555 -0.072684  0.328045
# temp_max           -0.228555  1.000000  0.875687 -0.164857
# temp_min           -0.072684  0.875687  1.000000 -0.074185
# wind                0.328045 -0.164857 -0.074185  1.000000
