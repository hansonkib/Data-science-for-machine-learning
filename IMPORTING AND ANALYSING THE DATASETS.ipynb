# %% [markdown]
# # IMPORTING AND ANALYSING THE DATASETS
# * Importing the datasets

# %%
import pandas as pd
data=pd.read_csv("seattle-weather.csv")
data
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012/01/01            0.0      12.8       5.0   4.7  drizzle
# 1     2012/01/02           10.9      10.6       2.8   4.5     rain
# 2     2012/01/03            0.8      11.7       7.2   2.3     rain
# 3     2012/01/04           20.3      12.2       5.6   4.7     rain
# 4     2012/01/05            1.3       8.9       2.8   6.1     rain
# 5     2012/01/06            2.5       4.4       2.2   2.2     rain
# 6     2012/01/07            0.0       7.2       2.8   2.3     rain
# 7     2012/01/08            0.0      10.0       2.8   2.0      sun
# 8     2012/01/09            4.3       9.4       5.0   3.4     rain
# 9     2012/01/10            1.0       6.1       0.6   3.4     rain
# 10    2012/01/11            0.0       6.1      -1.1   5.1      sun
# 11    2012/01/12            0.0       6.1      -1.7   1.9      sun
# 12    2012/01/13            0.0       5.0      -2.8   1.3      sun
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# showws only the first five items
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012/01/01            0.0      12.8       5.0   4.7  drizzle
# 1  2012/01/02           10.9      10.6       2.8   4.5     rain
# 2  2012/01/03            0.8      11.7       7.2   2.3     rain
# 3  2012/01/04           20.3      12.2       5.6   4.7     rain
# 4  2012/01/05            1.3       8.9       2.8   6.1     rain

# %%
# displaying the first ten items
data.head(10)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012/01/01            0.0      12.8       5.0   4.7  drizzle
# 1  2012/01/02           10.9      10.6       2.8   4.5     rain
# 2  2012/01/03            0.8      11.7       7.2   2.3     rain
# 3  2012/01/04           20.3      12.2       5.6   4.7     rain
# 4  2012/01/05            1.3       8.9       2.8   6.1     rain
# 5  2012/01/06            2.5       4.4       2.2   2.2     rain
# 6  2012/01/07            0.0       7.2       2.8   2.3     rain
# 7  2012/01/08            0.0      10.0       2.8   2.0      sun
# 8  2012/01/09            4.3       9.4       5.0   3.4     rain
# 9  2012/01/10            1.0       6.1       0.6   3.4     rain

# %%
# displaying the last five items
data.tail()
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1456  2015/12/27            8.6       4.4       1.7   2.9     fog
# 1457  2015/12/28            1.5       5.0       1.7   1.3     fog
# 1458  2015/12/29            0.0       7.2       0.6   2.6     fog
# 1459  2015/12/30            0.0       5.6      -1.0   3.4     sun
# 1460  2015/12/31            0.0       5.6      -2.1   3.5     sun

# %%
# diisplaying the shape of the data
data.shape
# Out:
# (1461, 6)

# %%
data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
# date             1461 non-null object
# precipitation    1461 non-null float64
# temp_max         1461 non-null float64
# temp_min         1461 non-null float64
# wind             1461 non-null float64
# weather          1461 non-null object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
# displaying the mean
data.mean()
# Out:
# precipitation     3.029432
# temp_max         16.439083
# temp_min          8.234771
# wind              3.241136
# dtype: float64

# %%
# displaying the median
data.median()
# Out:
# precipitation     0.0
# temp_max         15.6
# temp_min          8.3
# wind              3.0
# dtype: float64

# %%
data.std()
# Out:
# precipitation    6.680194
# temp_max         7.349758
# temp_min         5.023004
# wind             1.437825
# dtype: float64

# %%
data.max()
# Out:
# date             2015/12/31
# precipitation          55.9
# temp_max               35.6
# temp_min               18.3
# wind                    9.5
# weather                 sun
# dtype: object

# %%
data.min()
# Out:
# date             2012/01/01
# precipitation             0
# temp_max               -1.6
# temp_min               -7.1
# wind                    0.4
# weather             drizzle
# dtype: object

# %%
# displaying the number of non-null items in the colujmn
data.count()
# Out:
# date             1461
# precipitation    1461
# temp_max         1461
# temp_min         1461
# wind             1461
# weather          1461
# dtype: int64

# %%
# descriptive statistics summary
data.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000
